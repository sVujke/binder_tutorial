# %%
import pandas as pd 
import tensorflow

# %%
sample_df = pd.DataFrame({
    "A": [1,2,3],
    "B": [10,20,30],
    "C": ["txt", "video", "img"]
})

# %%
sample_df
# Out:
#    A   B      C
# 0  1  10    txt
# 1  2  20  video
# 2  3  30    img
